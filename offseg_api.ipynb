# %%
import requests
import pprint

# %%
import requests
import pprint
import json
import os

company_code = os.environ['OFFSEG_COMPANY_CODE']
user_code = os.environ['OFFSEG_USER_CODE']
password = os.environ['OFFSEG_PASSWORD']

POST_URL = "https://exsyscoopapi.offseg.obvious.jp/api/public/admin/login"
request_body = {'company_code': company_code, 'user_code': user_code, 'password': password}

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.post(POST_URL, json=request_body)

# レスポンスボディを出力する
pprint.pprint(response.json())
# Out:
# {'content': {'authentication_result': {'challenge_name': None,
#                                        'expiration_date': 1726723097000,
#                                        'session': None,
#                                        'token_info': {'id_token': 'eyJraWQiOiJuOXNHMlwvNW92Z3o0b2tDYzJidnVuYXVYTThTYnc4a01DNlZpYnVIanVWWT0iLCJhbGciOiJSUzI1NiJ9.....IRqMvU2v6QscCwpht3CfqCyYi3z6dy-XfwxqQ0BgrYe7cV4GLaGaHbHUmC9UqObGMjv0aMZj7lR6FwAXrt8xLZ17s9RYzTseFjzEdwyFe-U3kEc0lx8cyuW-M_FqGo2ZfmbY2p_OQhCRaWtgFR-v6eYuf6FYcZaHIqH2gn1nDBujC8FtODR5m-HvxkI-AKqX-2hBt4fj305GUd4RvlQBQqQvqPytw_H1GInpaZD3eE8pNSh6we0FleGLjqH_rIgpivaPUBqWkF9MYu8Dk_09W7Q3wMHTa5geJ9hVKZ5V1O5wgFxJN-MS5Gb9f7hLzyucM9mXrtyHGHOJR2H9pCs6lw',
# ...

# %%
import json

id_token = response.json()['content']['authentication_result']['token_info']['id_token']
refresh_token = response.json()['content']['authentication_result']['token_info']['refresh_token']
company_id = response.json()['content']['search_result']['company_id']
user_id = response.json()['content']['search_result']['user_id']
print(id_token)
print(company_id)
print(user_id)
# Out:
# eyJraWQiOiJuOXNHMlwvNW92Z3o0b2tDYzJidnVuYXVYTThTYnc4a01DNlZpYnVIanVWWT0iLCJhbGciOiJSUzI1NiJ9.....gEBvZqroxhEvF1qSVqwXL1X9dibqSLJljC8ovfgwJ415Zj9aHI1ryaE9UA4WV-wPyJrVMVlUe3RdalT09OYBrRMx-Ff9FMk3TPnVsLRh8NO5z3EaoCGxDGHEkVCeIIqAck4wPyCGaL4wKBCqNf8pv3BDx4cWoGqouo9hE3KTfOXM4o_xS0Ei67c93890JfWJ-tCvym62YIoavx4CvLz-N6C1Jhvmjo4Z8LMLJdr6bu6EJKKCKEa5fa-hQmxGeCVL_WVxv8oEGYo9n7XMKmO8OEnxOyJ5j_JC-KeQG_DsYPlVqUd5T_elw8gkVSczRs-cw5hv72dJ0TNgI4R-vAb8_w
# 492
# 12649

# %%
#管理者ログイン(管理者のみ)
import json

def update_id_token(id_token,user_id,company_id,refresh_token):
    REFRESH_TOKEN_URL = "https://exsyscoopapi.offseg.obvious.jp/api/public/login/reissue-token"
    request_headers = {'id_token': id_token ,'operation_user_id': str(user_id),'operation_company_id': str(company_id),'Content-Type': 'application/json'}
    request_body = {'refresh_token': refresh_token}

    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.put(REFRESH_TOKEN_URL, headers=request_headers,data=json.dumps(request_body))

    # レスポンスボディを出力する
    pprint.pprint(response.json())
 
    new_id_token = response.json()['content']['id_token']
    
    return new_id_token

# %%
#ログイン（ドライバでログインできるが使わない）

LOGIN_INFO_URL = "https://exsyscoopapi.offseg.obvious.jp/api/public/login"
request_body = {'company_code': company_code, 'user_code': user_code, 'password': password}

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.post(LOGIN_INFO_URL, json=request_body)

# レスポンスボディを出力する
pprint.pprint(response.json())
# Out:
# {'content': {'authentication_result': {'challenge_name': None,
#                                        'expiration_date': 1726723400000,
#                                        'session': None,
#                                        'token_info': {'id_token': 'eyJraWQiOiJuOXNHMlwvNW92Z3o0b2tDYzJidnVuYXVYTThTYnc4a01DNlZpYnVIanVWWT0iLCJhbGciOiJSUzI1NiJ9.....Tq0B2DYls7qZw_2H0R71JfatWUwiwgdyRmPvI4a6EDUwNc4H32Ro3qgo2iWAO3Xc721ETIIdIcoxyK_Xh25rS3gpa4aYmYSmQcdqZIqLNoOxpsz2mw9paeE_jqhLBALO9VjdHZy9542faIsLSkYmccf5n-mJLHUjYGP6v-GYQUGIukcE38Wa6oN00lps0VibgS3M9vuCsOn1ENvUiwVQNyi6JwKAHR4QvKembXUuOR-c7pQphzUKqE-G0_2gfNpBb02hnEesubLLnoj6_Aai9rOa4YUWQuxs8EIQhYPIu4RJHFa7H4ja_73RCdS-yhlj2ua2HxSbf_tbtysnjMsjPQ',
# ...

# %%
id_token = update_id_token(id_token,user_id,company_id,refresh_token)
# Out:
# {'content': {'expiration_date': 1726742328000,
#              'id_token': 'eyJraWQiOiJuOXNHMlwvNW92Z3o0b2tDYzJidnVuYXVYTThTYnc4a01DNlZpYnVIanVWWT0iLCJhbGciOiJSUzI1NiJ9.....LjBT5bLbY6HQ5VRrSxRU5tU-v7-wuKoSul8JnpZ3mNtK8QxNhjDyqJRNwrf3qee_kJqOVTtLN5mhFrU6eswsckcpOgMT4XAP8UrxfLckxyS2zHXR5JXKKvBVe6rCG5YGeE8WN6J4F5_XKCZWXRukxSMDU4wRjdI-PEpzvIkfqG8boHPZzQ3ONX9mK-DmlrQOf1xUwm53wApJlUCWNYHdoCMg4LX50WfhgQi2yxSOPNbAdx4ymFLTEl92vwTN9ztC1vK6kNL-7Ehp4AYb8rO4WrvSAfJeT09GEh9vgrJOHafHGb9VrEaFYMDXBjOKKmpWSmc-IF_WoJh5CCTDNATTzg'},
#  'resultcode': 0}

# %% [markdown]
# ## センサデータの取得

# %%
#本番環境URL

URL = 'https://exsyscoopapi.offseg.obvious.jp/api/public'

# %%
## アドミン情報を取得
## 実行ユーザIDや実行カンパニーID、トークン情報を取得
import requests
import pprint
import json
import os

company_code = os.environ['OFFSEG_COMPANY_CODE']
user_code = os.environ['OFFSEG_USER_CODE']
password = os.environ['OFFSEG_PASSWORD']


def get_admin_info(company_code,user_code,password):
    ADMIN_URL = f"{URL}/admin/login"
    request_body = {'company_code': company_code, 'user_code': user_code, 'password': password}

    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.post(ADMIN_URL, json=request_body)

    id_token = response.json()['content']['authentication_result']['token_info']['id_token']
    refresh_token = response.json()['content']['authentication_result']['token_info']['refresh_token']
    company_id = response.json()['content']['search_result']['company_id']
    user_id = response.json()['content']['search_result']['user_id']

    # レスポンスボディを出力する
    #pprint.pprint(response.json())

    return id_token,refresh_token,company_id,user_id

# %%
#定常センサデータ取得

def get_ticket_info_const(car_id_list,id_token,user_id,company_id,search_periodic_from,search_periodic_to):
    SENSOR_POST_URL = f"{URL}/periodic_data/acquisition_request"

    request_headers = {'id_token': id_token ,
                    'operation_user_id': str(user_id),
                    'operation_company_id': str(company_id)
                    }
    request_body = {
                    'request_id':1,
                    'search_periodic_from':search_periodic_from,
                    'search_periodic_to':search_periodic_to,
                    'car_id_list':car_id_list,
                    'output_format':'02'#JSON
                    }

    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.post(SENSOR_POST_URL,headers=request_headers,json=request_body)
    resultcode = response.json()['resultcode']
    # レスポンスボディを出力する
    #pprint.pprint(response.json())
    resultcode = response.json()['resultcode']
    if resultcode==0:
        ticket_id = response.json()['content']['ticket_id']
    else:
        ticket_id = response.json()['content']['messages']
    return resultcode,ticket_id

# %%
#定常センサデータ取得

def get_ticket_info_trip(car_id_list,id_token,user_id,company_id,search_periodic_from,search_periodic_to):
    TRIP_POST_URL = f"{URL}/periodic_data/trip_acquisition_request"

    request_headers = {'id_token': id_token ,'operation_user_id': str(user_id),'operation_company_id': str(company_id)}
    request_body = {'search_periodic_from':search_periodic_from,
                    'search_periodic_to':search_periodic_to,
                    'request_id':1,
                    'car_id_list':car_id_list,
                    'output_format':'02' #JSON
                    }
    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.post(TRIP_POST_URL,headers=request_headers,json=request_body)

    # レスポンスボディを出力する
    #pprint.pprint(response.json())
    resultcode = response.json()['resultcode']
    if resultcode==0:
        ticket_id = response.json()['content']['ticket_id']
    else:
        ticket_id = response.json()['content']['messages']
    return resultcode,ticket_id

# %%
def get_file_info(id_token,user_id,company_id,ticket_id):

#定常センサデータ取得状況確認

    ACQUITION_URL = "https://exsyscoopapi.offseg.obvious.jp/api/public/periodic_data/acquisition_status"

    request_headers = {
        'id_token': id_token ,
        'operation_user_id': str(user_id),
        'operation_company_id': str(company_id)
        }
    request_body = {'request_id':1,
                    'ticket_id':ticket_id
                    }
    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.post(ACQUITION_URL,headers=request_headers,json=request_body)

    # レスポンスボディを出力する
    #pprint.pprint(response.json())
    resultcode = response.json()['resultcode']
    if resultcode==0:
        file_info = response.json()['content']['file_info']
    else:
        file_info = response.json()['content']['messages']
    return resultcode,file_info

# %%
# 定常センサデータ収集情報取得
def get_sensor_data_url(id_token,user_id,company_id,ticket_id,file_id):

    FILE_GET_URL = f"{URL}/periodic_data/file_url"

    request_headers = {'id_token': id_token ,'operation_user_id': str(user_id),'operation_company_id': str(company_id)}
    request_body = {'request_id':1,
                    'ticket_id':ticket_id,
                    'file_id':file_id
                    }
    # POSTリクエストを、リクエストボディ付きで送信する
    response = requests.post(FILE_GET_URL,headers=request_headers,json=request_body)

    # レスポンスボディを出力する
    resultcode = response.json()['resultcode']
    if resultcode==0:
        file_url = response.json()['content']['presigned_url']
    else:
        file_url = response.json()['content']['messages']    

    return resultcode,file_url

# %%
## ADMIN情報を取得
print('admin info ==================\n')
id_token,refresh_token,company_id,user_id = get_admin_info(company_code=company_code,user_code=user_code,password=password)
print(company_id,user_id,id_token,refresh_token)
# Out:
# admin info ==================
#
# ...

# %% [markdown]
#     # 認証トークンの有効期限が切れていた場合
#
# ticket_id ===================================================================================================
# ['認識トークンの有効期限が切れています。']

# %%
from glob import glob
import json
import pandas as pd
from io import StringIO


def upload_json_file():
    folder_list = glob("./sensor_data/*")
    print(folder_list)
    
    
    for folder in folder_list:
        folder_name = folder.split('\\')[-1]
        print(folder_name)
        json_list = glob(f"{folder}/*.json")
        print(json_list)
        json_text = ""
        for r,json_file in enumerate(json_list):
            with open(json_file,'r',encoding='utf-8') as f:
                json_text += f.read()
        with open("tmp_json_file.json",'w',encoding='utf-8') as f1:
            f1.write(json_text)
        # StringIOオブジェクトでラップ
        json_data = StringIO(json_text)
        # JSONデータを読み込む
        df = pd.read_json(json_data)
        if not os.path.exists('./sensor_csv_data'):
            os.mkdir('./sensor_csv_data')
        df.to_csv(f'./sensor_csv_data/{folder_name}.csv',index=False)

# %%
import urllib.request
import sys
import time
import tarfile
import pandas as pd


def upload_offseg_sensor_data(date_str,car_id_list,id_token,user_id,company_id):
    #car_id_list = [4051]
    #date_str = '2024091712'#対象の日付を指定
    #1日単位で設定しようとしたが、ファイルサイズが大きくなりすぎのため、1時間単位に修正
    search_periodic_from = f'{date_str}0000'
    search_periodic_to = f'{date_str}5959'


    print('ticket_id ===================================================================================================')
    resultcode_ticket_info,ticket_id = get_ticket_info_const(car_id_list=car_id_list,id_token=id_token,user_id=user_id,company_id=company_id,search_periodic_from=search_periodic_from,search_periodic_to=search_periodic_to)

    if resultcode_ticket_info == 0:
        time.sleep(1)#SLEEPをいれないと、データが取得できない(たぶん生成するまでのラグがある？)
        print('ticket_id:',ticket_id)
        print('file_info ===================================================================================================')
        result_code_file_info,file_infos = get_file_info(id_token=id_token,user_id=user_id,company_id=company_id,ticket_id=ticket_id)
        
        #定常センサデータ取得状況確認
        if result_code_file_info == 0:
            print(file_infos)
            print('file_url ===================================================================================================')
            for file_info in file_infos:
                car_id = file_info['car_id']
                file_id = file_info['file_id']
                resultcode_url,file_url = get_sensor_data_url(id_token=id_token,user_id=user_id,company_id=company_id,ticket_id=ticket_id,file_id=file_id)
                #fileのダウンロード
                if resultcode_url == 0:
                    print(file_url)
                    if not os.path.exists('./tar_file'):
                        os.mkdir('./tar_file')
                    download_file = f'./tar_file/car_id_{car_id}-day_{date_str}.tar.gz'
                    urllib.request.urlretrieve(file_url,"{0}".format(f"{download_file}"))
                    #ダウンロードしたファイルを解凍する
                    json_list = []
                    json_text = ""
                    with tarfile.open(f'{download_file}') as tar:
                        for i in tar.getmembers():
                            if i.name[0] == '/' or i.name[0:2] == '..':
                                exit()
                            json_list.append(i.name)
                        if not os.path.exists(f'./sensor_data'):
                            os.mkdir(f'./sensor_data') 
                        if not os.path.exists(f'./sensor_data/car_id_{car_id}-date_{search_periodic_from}'):
                                os.mkdir(f'./sensor_data/car_id_{car_id}-date_{search_periodic_from}')
                        tar.extractall(path=f'./sensor_data/car_id_{car_id}-date_{search_periodic_from}')
                    
                    #jsonファイルを結合してcsvに変換する
                    for r,json_file in enumerate(json_list):
                        json_file_path = f'./sensor_data/car_id_{car_id}-date_{search_periodic_from}/{json_file}'
                        with open(json_file_path,'r',encoding='utf-8') as f:
                            json_text += f.read()
                    # StringIOオブジェクトでラップ
                    json_data = StringIO(json_text)
                    # JSONデータを読み込む
                    df = pd.read_json(json_data)
                    
                    if not os.path.exists('./sensor_csv_data'):
                        os.mkdir('./sensor_csv_data')
                    df.to_csv(f'./sensor_csv_data/car_id_{car_id}-date_{search_periodic_from}.csv',index=False)

                else:
                    print(file_url)
        else:
            print(f"{file_infos}")
    else:
        print(f"{ticket_id}")

# %%
#1時間ごとのデータを取得する

for h in range(0,24):
    car_id_list = [4051]
    date_str = f'20240917{h:02}'
    print(date_str)
    upload_offseg_sensor_data(date_str=date_str,car_id_list=car_id_list,id_token=id_token,user_id=user_id,company_id=company_id)
# Out:
# 2024091700
# ticket_id ===================================================================================================
# ticket_id: 374d9a15-a9e9-429f-96f8-fc8c2c697b06
# file_info ===================================================================================================
# [{'status': '02', 'error_info': [{'error_code': 570002, 'error_field': None, 'error_message': '対象データが存在しません。'}], 'file_id': 1, 'car_id': 4051, 'file_created_datetime': None}]
# file_url ===================================================================================================
# ['対象データが存在しません。']
# 2024091701
# ticket_id ===================================================================================================
# ticket_id: 52687cbe-3737-467f-b489-6594d16909f9
# file_info ===================================================================================================
# ...

# %%
import os
import snowflake.connector #Snowflake接続用


SNOWFLAKE_USER = os.environ['SNOWFLAKE_USER'] #snowflakeのユーザID
SNOWFLAKE_PASSWORD = os.environ['SNOWFLAKE_PASSWORD'] #snowflakeのパスワード
SNOWFLAKE_ACCOUNT = os.environ['SNOWFLAKE_ACCOUNT']

def send_sql_to_snowflake(sqls):
    ctx = snowflake.connector.connect(
        user=SNOWFLAKE_USER,
        password=SNOWFLAKE_PASSWORD,
        account=SNOWFLAKE_ACCOUNT,
        warehouse='COMPUTE_WH'
        )
    #接続確認
    cs = ctx.cursor()
    try:
        cs.execute(sqls)
        #df = cs.fetch_pandas_all()
        all_row = cs.fetchall()
        #print(one_row[0])
    finally:
        cs.close()
    ctx.close()
    
    return all_row
    #return df

# %%
import os
import pandas as pd
import snowflake.connector
from snowflake.connector.pandas_tools import write_pandas

# Snowflakeへの接続
def upload_snowflake(database,schema,table,upload_df):
    conn = snowflake.connector.connect(
        user=os.environ['SNOWFLAKE_USER'],
        password=os.environ['SNOWFLAKE_PASSWORD'],
        account=os.environ['SNOWFLAKE_ACCOUNT'],
        database=database,
        schema=schema
    )

    # TABLEへのDataFrameの書き込み
    success, nchunks, nrows, output = write_pandas(
        conn=conn,
        df=upload_df,
        table_name=table
    )

    print(success, nchunks, nrows, output)
    sql = f"""
        create or replace table {database}.{schema}.{table} as
        select distinct *
        from {database}.{schema}.{table};
    """

    #send_sql_to_snowflake(sql) #重複しているデータを削除する

# %%
upload_json_file()
# Out:
# ['./sensor_data\\car_id_4051-date_20240917110000', './sensor_data\\car_id_4051-date_20240917120000']
# car_id_4051-date_20240917110000
# ['./sensor_data\\car_id_4051-date_20240917110000\\4051751611bb-22d8-416c-a5fd-1d7bd11e10cd_1.json', './sensor_data\\car_id_4051-date_20240917110000\\4051751611bb-22d8-416c-a5fd-1d7bd11e10cd_2.json', './sensor_data\\car_id_4051-date_20240917110000\\4051751611bb-22d8-416c-a5fd-1d7bd11e10cd_3.json', './sensor_data\\car_id_4051-date_20240917110000\\4051751611bb-22d8-416c-a5fd-1d7bd11e10cd_4.json', './sensor_data\\car_id_4051-date_20240917110000\\4051751611bb-22d8-416c-a5fd-1d7bd11e10cd_5.json']
# car_id_4051-date_20240917120000
# ...

# %% [markdown]
# ## 現在の場所情報を取得

# %%
CURRENT_LOCATION = 'https://exsyscoopapi.offseg.obvious.jp/api/public/car-management/car-place'

request_headers = {
                    'id_token': id_token ,
                   'operation_user_id': str(user_id),
                   'operation_company_id': str(company_id)
                   }
request_body = {
                'limit':10,
                'sort_order':1
                }

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.get(CURRENT_LOCATION,headers=request_headers,json=request_body)

# レスポンスボディを出力する
pprint.pprint(response.json())

for driver in response.json()['content']['search_result']:
    print(driver)
# Out:
# {'content': {'has_next': False,
#              'operation_unit_number': '0',
#              'owned_unit_number': '5',
#              'remaining_movie': '90',
#              'search_result': [{'car_code': '00000001 三重 ３０２ さ ３４-００',
#                                 'car_id': 4051,
#                                 'connection_status': '0',
#                                 'device_id_error': '1',
#                                 'device_setting_updated_datetime': '20240822T163717.295+0900',
#                                 'device_unique_id': 4051,
#                                 'direction': 16,
#                                 'driver_name': '(DN)里村祥太_dr',
#                                 'lat': 35.072415,
#                                 'lock': '0',
#                                 'lon': 136.641083,
#                                 'organize_name': 'ドラみるプロジェクト ドラみる開発チーム デンソー',
#                                 'positioning_status': '1',
# ...

# %% [markdown]
# ## ログイン情報を取得

# %%
LOGIN_MASTER_URL= 'https://exsyscoopapi.offseg.obvious.jp/api/public/master/login'

request_headers = {
                    'id_token': id_token ,
                    'operation_user_id': str(user_id),
                    'operation_company_id': str(company_id)
                  }
#request_body = {'limit':10,'sort_order':1}

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.get(LOGIN_MASTER_URL,headers=request_headers)

# レスポンスボディを出力する
pprint.pprint(response.json())
# Out:
# {'content': {'has_next': False,
#              'search_result': [{'comment': '',
#                                 'email': 'kazuhiro.fukushima.j3u@jp.denso.com',
#                                 'organize_name': 'ドラみるプロジェクト ドラみる開発チーム',
#                                 'permission_name': '統括管理者',
#                                 'user_code': 'DN_Fukushima',
#                                 'user_id': 12650,
#                                 'user_name': '(DN)福島一博'},
#                                {'comment': '',
#                                 'email': 'tatsuya.ikegami.j2k@jp.denso.com',
#                                 'organize_name': 'ドラみるプロジェクト ドラみる開発チーム',
#                                 'permission_name': '統括管理者',
#                                 'user_code': 'DN_Ikegami',
#                                 'user_id': 12652,
#                                 'user_name': '(DN)池上達也'},
#                                {'comment': '-',
# ...

# %% [markdown]
# ## イベント動画を取得する

# %%
EVENT_LIST_URL= 'https://exsyscoopapi.offseg.obvious.jp/api/public/event-management/video/list'

request_headers = {'id_token': id_token ,
                   'operation_user_id': str(user_id),
                   'operation_company_id': str(company_id),
                   'Content-Type': 'application/json'}
request_body = {'condition':{
                #'driver_id':10173,
                'target_start_date':'2024/09/01',
                'target_end_date':'2024/09/05',
                'condition_event':{
                    'time_specified_flag':'false',
                    'offseg_viewer_flag':'false'

                },
                "sort_item": "1",
                "sort_order": "1"
                }
                }

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.post(EVENT_LIST_URL,headers=request_headers,data=json.dumps(request_body))

# レスポンスボディを出力する
pprint.pprint(response.json())
# Out:
# {'content': {'has_next': False, 'search_result': []}, 'resultcode': 0}

# %%
#イベントビデオを取得
event_id = 1
GET_EVENT_VIDEO_URL= f'https://exsyscoopapi.offseg.obvious.jp/api/public/event-management/video/{event_id}'

request_headers = {'id_token': id_token ,
                   'operation_user_id': str(user_id),
                   'operation_company_id': str(company_id),
                   'Content-Type': 'application/json'}


# POSTリクエストを、リクエストボディ付きで送信する
response = requests.get(EVENT_LIST_URL,headers=request_headers)

# レスポンスボディを出力する
pprint.pprint(response.json())
# Out:
# {'content': {'messages': ['データが存在しません。']}, 'resultcode': 2}

# %% [markdown]
# ## ドライバー情報を取得する

# %%
DRIVER_LIST_URL= 'https://exsyscoopapi.offseg.obvious.jp/api/public/master/driver'

request_headers = {'id_token': id_token ,'operation_user_id': str(user_id),'operation_company_id': str(company_id)}
#request_body = {'limit':10,'sort_order':1}

# POSTリクエストを、リクエストボディ付きで送信する
response = requests.get(DRIVER_LIST_URL,headers=request_headers)

# レスポンスボディを出力する
pprint.pprint(response.json())

for i in response.json()['content']['search_result']:
    print(i)
# Out:
# {'content': {'driver_comment_labels': {'driver_comment_label1': '備考1',
#                                        'driver_comment_label10': '備考10',
#                                        'driver_comment_label2': '備考2',
#                                        'driver_comment_label3': '備考3',
#                                        'driver_comment_label4': '備考4',
#                                        'driver_comment_label5': '備考5',
#                                        'driver_comment_label6': '備考6',
#                                        'driver_comment_label7': '備考7',
#                                        'driver_comment_label8': '備考8',
#                                        'driver_comment_label9': '備考9'},
#              'has_next': False,
#              'search_result': [{'birthday': '-',
#                                 'card_id': '-',
#                                 'comment1': '-',
#                                 'comment10': '-',
# ...
